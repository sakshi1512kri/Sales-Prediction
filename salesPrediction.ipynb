# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\saksh\Downloads\archive (6)\Advertising.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 df = pd.read_csv("C:\\Users\saksh\Downloads\archive (6)\Advertising.csv")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 df.keys()
#
# NameError: name 'df' is not defined

# %%
X = df[['TV', 'Radio', 'Newspaper']]
y = df['Sales']

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 regr = linear_model.LinearRegression()
#       2 regr.fit(X_train, y_train)
#
# NameError: name 'linear_model' is not defined

# %%
predictedSales = regr.predict(X_test).tolist()
expectedSales = y_test.tolist()

# %%
tup = list(zip(expectedSales, predictedSales))
resultDf = pandas.DataFrame(tup, columns=['expectedSales', 'predictedSales'])
resultDf
# Out:
#     expectedSales  predictedSales
# 0            10.6       12.538251
# 1            23.8       23.636760
# 2            11.5       13.673586
# 3             7.2       12.767170
# 4            11.3        9.923658
# 5            22.6       20.699739
# 6            15.0       17.798552
# 7            19.7       19.708312
# 8            19.6       18.300356
# 9            16.7       17.038259
# 10           12.4       10.682736
# 11           14.1       13.733696
# 12            9.7        8.272410
# 13            3.2        5.235619
# 14           10.3        9.729972
# 15           12.9       12.011819
# 16           14.9       15.182768
# 17           11.2        9.926295
# 18            8.4        7.389476
# 19            6.9        4.511269
# 20            4.8        3.642608
# 21            9.4        6.555715
# 22           20.8       21.008993
# 23           24.7       22.038585
# 24            8.7       12.244266
# 25           20.7       19.468505
# ...
